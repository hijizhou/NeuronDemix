# %%
# General Dependencies
import os
import numpy as np


# Denoising dependencies
from trefide.pmd import batch_decompose,\
                        batch_recompose,\
                        overlapping_batch_decompose,\
                        overlapping_batch_recompose,\
                        determine_thresholds


from trefide.reformat import overlapping_component_reformat

# Plotting & Video Rendering Dependencies
import funimag

import matplotlib.pyplot as plt
from trefide.plot import pixelwise_ranks
from trefide.video import play_cv2

# Set Demo Dataset Location
ext = os.path.join("..", "example_movies")
filename = os.path.join(ext, "demoMovie.tif")

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Load Data

# %%
from skimage import io
mov = io.imread(filename).transpose([1,2,0])[:60,:60,:]
mov = np.asarray(mov,order='C',dtype=np.float64)
print(mov.shape)

fov_height, fov_width, num_frames = mov.shape
# Out:
# (60, 60, 2000)

# %% [markdown]
# # Set Params

# %%
# Maximum of rank 50 blocks (safeguard to terminate early if this is hit)
max_components = 50

# Enable Decimation 
max_iters_main = 10
max_iters_init = 40
d_sub=2
t_sub=2

# Defaults
consec_failures = 3
tol = 0.0005

# Set Blocksize Parameters
block_height = 20
block_width = 20
overlapping = True

# %% [markdown]
# # Compress Video

# %% [markdown]
# ## Simulate Critical Region with Noise

# %%
spatial_thresh, temporal_thresh = determine_thresholds((fov_height, fov_width, num_frames),
                                                       (block_height, block_width),
                                                       consec_failures, max_iters_main, 
                                                       max_iters_init, tol, 
                                                       d_sub, t_sub, 5, True)

# %% [markdown]
# ## Decompose Each Block Into Spatial & Temporal Components

# %%
# Blockwise Parallel, Single Tiling
if not overlapping:    
    spatial_components,\
    temporal_components,\
    block_ranks,\
    block_indices = batch_decompose(fov_height, fov_width, num_frames,
                                    mov, block_height, block_width,
                                    max_components, consec_failures,
                                    max_iters_main, max_iters_init, tol,
                                    d_sub=d_sub, t_sub=t_sub)
    
 # Blockwise Parallel, 4x Overlapping Tiling
else:   
    spatial_components,\
    temporal_components,\
    block_ranks,\
    block_indices,\
    block_weights = overlapping_batch_decompose(fov_height, fov_width, num_frames,
                                                mov, block_height, block_width,
                                                spatial_thresh, temporal_thresh,
                                                max_components, consec_failures,
                                                max_iters_main, max_iters_init, tol,
                                                d_sub=d_sub, t_sub=t_sub)

# %% [markdown]
# # Reconstruct Denoised Video

# %%
# Single Tiling (No need for reqweighting)
if not overlapping: 
    mov_denoised = np.asarray(batch_recompose(spatial_components,
                                              temporal_components,
                                              block_ranks,
                                              block_indices))
# Overlapping Tilings With Reweighting
else:  
    mov_denoised = np.asarray(overlapping_batch_recompose(fov_height, fov_width, num_frames,
                                                          block_height, block_width,
                                                          spatial_components,
                                                          temporal_components,
                                                          block_ranks,
                                                          block_indices,
                                                          block_weights))

# %% [markdown]
# # Produce Diagnostics

# %% [markdown]
# ### Single Tiling Pixel-Wise Ranks

# %%
if overlapping:
    pixelwise_ranks(block_ranks['no_skew']['full'], fov_height, fov_width, num_frames, block_height, block_width)
else:
    pixelwise_ranks(block_ranks, fov_height, fov_width, num_frames, block_height, block_width)

# %% [markdown]
# ### Correlation Images

# %%
# !pip uninstall cvxpy --y
# !pip uninstall numpy --y
# !pip install Cython
# !pip install numpy
# !conda install -c cvxgrp cvxpy
# Out:
# WARNING: Skipping cvxpy as it is not installed.
# Found existing installation: numpy 1.18.1
# Uninstalling numpy-1.18.1:
#   Successfully uninstalled numpy-1.18.1
# Collecting Cython
#   Downloading Cython-0.29.15-cp36-cp36m-manylinux1_x86_64.whl (2.1 MB)
#      |################################| 2.1 MB 21.2 MB/s eta 0:00:01
# ERROR: trefide 0.0.0 requires numpy, which is not installed.
# Installing collected packages: Cython
# Successfully installed Cython-0.29.15
# Collecting numpy
#   Using cached numpy-1.18.1-cp36-cp36m-manylinux1_x86_64.whl (20.1 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.18.1
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# !conda install -c cvxgrp cvxpy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
from funimag.plots import util_plot
# Out:
# [autoreload of numpy.core.multiarray failed: Traceback (most recent call last):
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/numpy/core/multiarray.py", line 78, in <module>
#     def empty_like(prototype, dtype=None, order=None, subok=None, shape=None):
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/numpy/core/overrides.py", line 209, in decorator
#     docs_from_dispatcher=docs_from_dispatcher)(implementation)
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/numpy/core/overrides.py", line 171, in decorator
#     add_docstring(implementation, dispatcher.__doc__)
# RuntimeError: empty_like method already has a docstring
# ]
# [autoreload of numpy.core.overrides failed: Traceback (most recent call last):
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/numpy/core/overrides.py", line 47, in <module>
#     """)
# RuntimeError: implement_array_function method already has a docstring
# ]
# [autoreload of numpy.lib failed: Traceback (most recent call last):
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/numpy/lib/__init__.py", line 47, in <module>
#     __all__ += type_check.__all__
# NameError: name 'type_check' is not defined
# ]
# [autoreload of numpy.lib.scimath failed: Traceback (most recent call last):
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/numpy/lib/scimath.py", line 21, in <module>
#     import numpy.core.numerictypes as nt
# AttributeError: module 'numpy.core' has no attribute 'numerictypes'
# ]
# [autoreload of numpy.lib.index_tricks failed: Traceback (most recent call last):
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/numpy/lib/index_tricks.py", line 13, in <module>
#     import numpy.matrixlib as matrixlib
# AttributeError: module 'numpy' has no attribute 'matrixlib'
# ]
# [autoreload of numpy.matrixlib failed: Traceback (most recent call last):
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/numpy/matrixlib/__init__.py", line 8, in <module>
#     __all__ = defmatrix.__all__
# NameError: name 'defmatrix' is not defined
# ]
# [autoreload of numpy.ma.core failed: Traceback (most recent call last):
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/numpy/ma/core.py", line 39, in <module>
#     import numpy.core.numerictypes as ntypes
# AttributeError: module 'numpy.core' has no attribute 'numerictypes'
# ]
# [autoreload of numpy.testing failed: Traceback (most recent call last):
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/numpy/testing/__init__.py", line 18, in <module>
#     __all__ = _private.utils.__all__ + ['TestCase', 'run_module_suite']
# NameError: name '_private' is not defined
# ]
# [autoreload of numpy.testing._private.utils failed: Traceback (most recent call last):
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/usr/local/envs/neurondemix/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/usr/local/envs/neurondemix/lib/python3.6/site-packages/numpy/testing/_private/utils.py", line 57, in <module>
#     HAS_LAPACK64 = hasattr(numpy.__config__, 'lapack_ilp64_opt_info')
# AttributeError: module 'numpy' has no attribute '__config__'
# ]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-d0efe00726e4> in <module>
# ----> 1 from funimag.plots import util_plot
#
# /usr/local/envs/neurondemix/lib/python3.6/site-packages/funimag/plots/util_plot.py in <module>
#       9
#      10 from .. import utils
# ---> 11 from .. import superpixel_analysis as sup
#      12
#      13
#
# /usr/local/envs/neurondemix/lib/python3.6/site-packages/funimag/superpixel_analysis.py in <module>
#      10 import scipy.sparse
#      11 import scipy
# ---> 12 import cvxpy as cvx
#      13
#      14 from mpl_toolkits.axes_grid1 import make_axes_locatable
#
# ModuleNotFoundError: No module named 'cvxpy'

# %%
util_plot.comparison_plot([mov, mov_denoised + np.random.randn(np.prod(mov.shape)).reshape(mov.shape)*.01],
                plot_orientation="vertical")
# Out:
# Local correlation:  range [2.1e-01 9.3e-01]
# Local correlation:  range [6.1e-01 1.0e+00]
# Local correlation:  range [-2.4e-01 2.3e-01]

# %% [markdown]
# ## Render Videos & Residual

# %%
play_cv2(np.vstack([mov, mov_denoised, mov-mov_denoised]), magnification=2)

# %% [markdown]
# # Save Results

# %%
U, V = overlapping_component_reformat(fov_height, fov_width, num_frames,
                                      block_height, block_width,
                                      spatial_components,
                                      temporal_components,
                                      block_ranks,
                                      block_indices,
                                      block_weights)

# %%
np.savez(os.path.join(ext, "demo_results.npz"), U, V,block_ranks,block_height,block_width)
